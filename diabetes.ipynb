# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/diabetes.csv")

# %%
df.head()
# Out:
#    Index  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0    0.0            6      148             72             35        0  33.6
# 1    1.0            1       85             66             29        0  26.6
# 2    2.0            8      183             64              0        0  23.3
# 3    3.0            1       89             66             23       94  28.1
# 4    4.0            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  Outcome.1
# 0                     0.627   50        1        1.0
# 1                     0.351   31        0       -1.0
# 2                     0.672   32        1        1.0
# 3                     0.167   21        0       -1.0
# 4                     2.288   33        1        1.0

# %%
# !ls
# Out:
# diabetes.csv  sample_data

# %%
df.tail()
# Out:
#      Index  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763    NaN           10      101             76             48      180  32.9
# 764    NaN            2      122             70             27        0  36.8
# 765    NaN            5      121             72             23      112  26.2
# 766    NaN            1      126             60              0        0  30.1
# 767    NaN            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  Outcome.1
# 763                     0.171   63        0        NaN
# 764                     0.340   27        0        NaN
# 765                     0.245   30        0        NaN
# 766                     0.349   47        1        NaN
# 767                     0.315   23        0        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Index                     10 non-null     float64
#  1   Pregnancies               768 non-null    int64
#  2   Glucose                   768 non-null    int64
#  3   BloodPressure             768 non-null    int64
#  4   SkinThickness             768 non-null    int64
#  5   Insulin                   768 non-null    int64
#  6   BMI                       768 non-null    float64
#  7   DiabetesPedigreeFunction  768 non-null    float64
#  8   Age                       768 non-null    int64
#  9   Outcome                   768 non-null    int64
#  10  Outcome.1                 27 non-null     float64
# dtypes: float64(4), int64(7)
# memory usage: 66.1 KB

# %%
df.isnull().sum()
# Out:
# Index                       758
# Pregnancies                   0
# Glucose                       0
# BloodPressure                 0
# SkinThickness                 0
# Insulin                       0
# BMI                           0
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# Outcome.1                   741
# dtype: int64

# %%
df.count()
# Out:
# Index                        10
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# Outcome.1                    27
# dtype: int64

# %%
df.mean()
# Out:
# Index                         4.500000
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# Outcome.1                     0.333333
# dtype: float64

# %%
df.std()
# Out:
# Index                         3.027650
# Pregnancies                   3.369578
# Glucose                      31.972618
# BloodPressure                19.355807
# SkinThickness                15.952218
# Insulin                     115.244002
# BMI                           7.884160
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Outcome                       0.476951
# Outcome.1                     0.960769
# dtype: float64

# %%
df.min()
# Out:
# Index                        0.000
# Pregnancies                  0.000
# Glucose                      0.000
# BloodPressure                0.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                          0.000
# DiabetesPedigreeFunction     0.078
# Age                         21.000
# Outcome                      0.000
# Outcome.1                   -1.000
# dtype: float64

# %%
df.max()
# Out:
# Index                         9.00
# Pregnancies                  17.00
# Glucose                     199.00
# BloodPressure               122.00
# SkinThickness                99.00
# Insulin                     846.00
# BMI                          67.10
# DiabetesPedigreeFunction      2.42
# Age                          81.00
# Outcome                       1.00
# Outcome.1                     1.00
# dtype: float64

# %% [markdown]
# df.describe()

# %%
df.drop(index = 0 , axis = 0)
# Out:
#      Index  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1      1.0            1       85             66             29        0  26.6
# 2      2.0            8      183             64              0        0  23.3
# 3      3.0            1       89             66             23       94  28.1
# 4      4.0            0      137             40             35      168  43.1
# 5      5.0            5      116             74              0        0  25.6
# ..     ...          ...      ...            ...            ...      ...   ...
# 763    NaN           10      101             76             48      180  32.9
# 764    NaN            2      122             70             27        0  36.8
# 765    NaN            5      121             72             23      112  26.2
# 766    NaN            1      126             60              0        0  30.1
# 767    NaN            1       93             70             31        0  30.4
#
# ...

# %% [markdown]
# df.drop(columns = "BMI" , axis = 1)

# %%
df.iloc[:,0]
# Out:
# 0      0.0
# 1      1.0
# 2      2.0
# 3      3.0
# 4      4.0
#       ...
# 763    NaN
# 764    NaN
# 765    NaN
# 766    NaN
# 767    NaN
# Name: Index, Length: 768, dtype: float64

# %%
df.iloc[:,-1]
# Out:
# 0      1.0
# 1     -1.0
# 2      1.0
# 3     -1.0
# 4      1.0
#       ...
# 763    NaN
# 764    NaN
# 765    NaN
# 766    NaN
# 767    NaN
# Name: Outcome.1, Length: 768, dtype: float64

# %%
df.iloc[:,-2]
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
df.iloc[:,-2]
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
df.corr()
# Out:
#                              Index  Pregnancies   Glucose  BloodPressure  \
# Index                     1.000000     0.241000  0.083791      -0.064371
# Pregnancies               0.241000     1.000000  0.129459       0.141282
# Glucose                   0.083791     0.129459  1.000000       0.152590
# BloodPressure            -0.064371     0.141282  0.152590       1.000000
# SkinThickness            -0.215358    -0.081672  0.057328       0.207371
# Insulin                   0.390339    -0.073535  0.331357       0.088933
# BMI                      -0.364901     0.017683  0.221071       0.281805
# DiabetesPedigreeFunction -0.264814    -0.033523  0.137337       0.041265
# Age                       0.288982     0.544341  0.263514       0.239528
# Outcome                   0.142134     0.221898  0.466581       0.065068
# Outcome.1                 0.142134     0.118031  0.471787       0.082255
#
#                           SkinThickness   Insulin       BMI  \
# ...

# %%
df.isnull().sum()
# Out:
# Index                       758
# Pregnancies                   0
# Glucose                       0
# BloodPressure                 0
# SkinThickness                 0
# Insulin                       0
# BMI                           0
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# Outcome.1                   741
# dtype: int64

# %%
df1 = pd.read_csv("/content/diabetes.csv")

# %%
print(df1)
# Out:
#      Index  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      0.0            6      148             72             35        0  33.6
# 1      1.0            1       85             66             29        0  26.6
# 2      2.0            8      183             64              0        0  23.3
# 3      3.0            1       89             66             23       94  28.1
# 4      4.0            0      137             40             35      168  43.1
# ..     ...          ...      ...            ...            ...      ...   ...
# 763    NaN           10      101             76             48      180  32.9
# 764    NaN            2      122             70             27        0  36.8
# 765    NaN            5      121             72             23      112  26.2
# 766    NaN            1      126             60              0        0  30.1
# 767    NaN            1       93             70             31        0  30.4
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Index                     10 non-null     float64
#  1   Pregnancies               768 non-null    int64
#  2   Glucose                   768 non-null    int64
#  3   BloodPressure             768 non-null    int64
#  4   SkinThickness             768 non-null    int64
#  5   Insulin                   768 non-null    int64
#  6   BMI                       768 non-null    float64
#  7   DiabetesPedigreeFunction  768 non-null    float64
#  8   Age                       768 non-null    int64
#  9   Outcome                   768 non-null    int64
#  10  Outcome.1                 27 non-null     float64
# dtypes: float64(4), int64(7)
# memory usage: 66.1 KB

# %%
df1.isnull().sum()
# Out:
# Index                       758
# Pregnancies                   0
# Glucose                       0
# BloodPressure                 0
# SkinThickness                 0
# Insulin                       0
# BMI                           0
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# Outcome.1                   741
# dtype: int64

# %%
new_df = df1.dropna()

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Index                     10 non-null     float64
#  1   Pregnancies               10 non-null     int64
#  2   Glucose                   10 non-null     int64
#  3   BloodPressure             10 non-null     int64
#  4   SkinThickness             10 non-null     int64
#  5   Insulin                   10 non-null     int64
#  6   BMI                       10 non-null     float64
#  7   DiabetesPedigreeFunction  10 non-null     float64
#  8   Age                       10 non-null     int64
#  9   Outcome                   10 non-null     int64
#  10  Outcome.1                 10 non-null     float64
# dtypes: float64(4), int64(7)
# memory usage: 960.0 bytes

# %%
df1.dropna(inplace = True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Index                     10 non-null     float64
#  1   Pregnancies               10 non-null     int64
#  2   Glucose                   10 non-null     int64
#  3   BloodPressure             10 non-null     int64
#  4   SkinThickness             10 non-null     int64
#  5   Insulin                   10 non-null     int64
#  6   BMI                       10 non-null     float64
#  7   DiabetesPedigreeFunction  10 non-null     float64
#  8   Age                       10 non-null     int64
#  9   Outcome                   10 non-null     int64
#  10  Outcome.1                 10 non-null     float64
# dtypes: float64(4), int64(7)
# memory usage: 960.0 bytes

# %%
df2 = pd.read_csv("/content/diabetes.csv")

# %%
df.fillna(111,inplace = True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Index                     10 non-null     float64
#  1   Pregnancies               768 non-null    int64
#  2   Glucose                   768 non-null    int64
#  3   BloodPressure             768 non-null    int64
#  4   SkinThickness             768 non-null    int64
#  5   Insulin                   768 non-null    int64
#  6   BMI                       768 non-null    float64
#  7   DiabetesPedigreeFunction  768 non-null    float64
#  8   Age                       768 non-null    int64
#  9   Outcome                   768 non-null    int64
#  10  Outcome.1                 27 non-null     float64
# dtypes: float64(4), int64(7)
# memory usage: 66.1 KB

# %%
df3 = pd.read_csv("/content/diabetes.csv")

# %%
df3['DiabetesPedigreeFunction'].fillna(111,inplace = True)
# Out:
# <ipython-input-42-67cf78272618>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df3['DiabetesPedigreeFunction'].fillna(111,inplace = True)

# %%
x = df3["DiabetesPedigreeFunction"].mean()

# %%
df3.median()
# Out:
# Index                         4.5000
# Pregnancies                   3.0000
# Glucose                     117.0000
# BloodPressure                72.0000
# SkinThickness                23.0000
# Insulin                      30.5000
# BMI                          32.0000
# DiabetesPedigreeFunction      0.3725
# Age                          29.0000
# Outcome                       0.0000
# Outcome.1                     1.0000
# dtype: float64
